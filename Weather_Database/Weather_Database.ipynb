# %%
# Import the dependencies.
import pandas as pd
import numpy as np

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
from citipy import citipy
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 754

# %%
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=31136f2fcced0d9407630756aa15f0d7

# %%
# Import the datetime module from the datetime library.
from datetime import datetime

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_country = city_weather["sys"]["country"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_weather_desc = city_weather["weather"][0]["description"]
        # Convert the date to ISO standard.
        #city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_weather_desc })

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | port alfred
# Processing Record 2 of Set 1 | tadine
# Processing Record 3 of Set 1 | busselton
# Processing Record 4 of Set 1 | faanui
# Processing Record 5 of Set 1 | puerto ayora
# Processing Record 6 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 7 of Set 1 | kibaya
# Processing Record 8 of Set 1 | rena
# Processing Record 9 of Set 1 | butaritari
# Processing Record 10 of Set 1 | matagami
# Processing Record 11 of Set 1 | punta arenas
# Processing Record 12 of Set 1 | dikson
# Processing Record 13 of Set 1 | vaini
# Processing Record 14 of Set 1 | touros
# Processing Record 15 of Set 1 | palm coast
# Processing Record 16 of Set 1 | port augusta
# Processing Record 17 of Set 1 | tiksi
# Processing Record 18 of Set 1 | klaksvik
# Processing Record 19 of Set 1 | tasiilaq
# Processing Record 20 of Set 1 | mahebourg
# Processing Record 21 of Set 1 | rikitea
# Processing Record 22 of Set 1 | itigi
# Processing Record 23 of Set 1 | mapiri
# Processing Record 24 of Set 1 | beringovskiy
# Processing Record 25 of Set 1 | port lincoln
# Processing Record 26 of Set 1 | albany
# Processing Record 27 of Set 1 | atuona
# Processing Record 28 of Set 1 | mana
# Processing Record 29 of Set 1 | cherskiy
# Processing Record 30 of Set 1 | poum
# Processing Record 31 of Set 1 | severo-kurilsk
# Processing Record 32 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 33 of Set 1 | pevek
# Processing Record 34 of Set 1 | bengkulu
# Processing Record 35 of Set 1 | upernavik
# Processing Record 36 of Set 1 | sentyabrskiy
# City not found. Skipping...
# Processing Record 37 of Set 1 | kamenskoye
# City not found. Skipping...
# Processing Record 38 of Set 1 | boende
# Processing Record 39 of Set 1 | hobart
# Processing Record 40 of Set 1 | daru
# Processing Record 41 of Set 1 | vaitupu
# City not found. Skipping...
# Processing Record 42 of Set 1 | coihaique
# Processing Record 43 of Set 1 | mataura
# Processing Record 44 of Set 1 | new norfolk
# Processing Record 45 of Set 1 | turgenevo
# Processing Record 46 of Set 1 | nikolskoye
# Processing Record 47 of Set 1 | sorong
# Processing Record 48 of Set 1 | kapaa
# Processing Record 49 of Set 1 | olinda
# Processing Record 50 of Set 1 | victoria
# Processing Record 1 of Set 2 | ushuaia
# Processing Record 2 of Set 2 | lorengau
# Processing Record 3 of Set 2 | labuhan
# Processing Record 4 of Set 2 | namatanai
# Processing Record 5 of Set 2 | rio gallegos
# Processing Record 6 of Set 2 | bambous virieux
# Processing Record 7 of Set 2 | saint-joseph
# Processing Record 8 of Set 2 | arraial do cabo
# Processing Record 9 of Set 2 | avarua
# Processing Record 10 of Set 2 | mount gambier
# Processing Record 11 of Set 2 | san quintin
# Processing Record 12 of Set 2 | saleaula
# City not found. Skipping...
# Processing Record 13 of Set 2 | puerto carreno
# Processing Record 14 of Set 2 | cape town
# Processing Record 15 of Set 2 | hobyo
# Processing Record 16 of Set 2 | naze
# Processing Record 17 of Set 2 | banamba
# Processing Record 18 of Set 2 | kholm
# Processing Record 19 of Set 2 | cabo san lucas
# Processing Record 20 of Set 2 | lososina
# Processing Record 21 of Set 2 | mao
# Processing Record 22 of Set 2 | constitucion
# Processing Record 23 of Set 2 | fortuna
# Processing Record 24 of Set 2 | mys shmidta
# City not found. Skipping...
# Processing Record 25 of Set 2 | cidreira
# Processing Record 26 of Set 2 | kitob
# Processing Record 27 of Set 2 | lata
# Processing Record 28 of Set 2 | nemuro
# Processing Record 29 of Set 2 | octeville
# Processing Record 30 of Set 2 | tuatapere
# Processing Record 31 of Set 2 | barrow
# Processing Record 32 of Set 2 | narsaq
# Processing Record 33 of Set 2 | idaho falls
# Processing Record 34 of Set 2 | provideniya
# Processing Record 35 of Set 2 | todos santos
# Processing Record 36 of Set 2 | kavieng
# Processing Record 37 of Set 2 | vila velha
# Processing Record 38 of Set 2 | salalah
# Processing Record 39 of Set 2 | lazaro cardenas
# Processing Record 40 of Set 2 | hampden
# Processing Record 41 of Set 2 | luderitz
# Processing Record 42 of Set 2 | chokurdakh
# Processing Record 43 of Set 2 | kokopo
# Processing Record 44 of Set 2 | cabanas
# Processing Record 45 of Set 2 | high level
# Processing Record 46 of Set 2 | gilgil
# City not found. Skipping...
# Processing Record 47 of Set 2 | jamestown
# Processing Record 48 of Set 2 | iqaluit
# Processing Record 49 of Set 2 | longyearbyen
# Processing Record 50 of Set 2 | maieru
# Processing Record 1 of Set 3 | tela
# Processing Record 2 of Set 3 | izhevskoye
# Processing Record 3 of Set 3 | laguna
# Processing Record 4 of Set 3 | gamba
# Processing Record 5 of Set 3 | yomou
# Processing Record 6 of Set 3 | narrabri
# Processing Record 7 of Set 3 | ribeira grande
# Processing Record 8 of Set 3 | aklavik
# Processing Record 9 of Set 3 | kaitangata
# Processing Record 10 of Set 3 | bethel
# Processing Record 11 of Set 3 | nouadhibou
# Processing Record 12 of Set 3 | timra
# Processing Record 13 of Set 3 | aksay
# Processing Record 14 of Set 3 | ponta delgada
# Processing Record 15 of Set 3 | batemans bay
# Processing Record 16 of Set 3 | guerrero negro
# Processing Record 17 of Set 3 | mehamn
# Processing Record 18 of Set 3 | souillac
# Processing Record 19 of Set 3 | hilo
# Processing Record 20 of Set 3 | troitsko-pechorsk
# Processing Record 21 of Set 3 | andenes
# Processing Record 22 of Set 3 | barcelos
# Processing Record 23 of Set 3 | attawapiskat
# City not found. Skipping...
# Processing Record 24 of Set 3 | manokwari
# Processing Record 25 of Set 3 | reinosa
# Processing Record 26 of Set 3 | da nang
# Processing Record 27 of Set 3 | nizhneyansk
# City not found. Skipping...
# Processing Record 28 of Set 3 | saldanha
# Processing Record 29 of Set 3 | lerwick
# Processing Record 30 of Set 3 | uzumlu
# City not found. Skipping...
# Processing Record 31 of Set 3 | acapulco
# Processing Record 32 of Set 3 | pathein
# Processing Record 33 of Set 3 | itaituba
# Processing Record 34 of Set 3 | cape coast
# Processing Record 35 of Set 3 | buchanan
# Processing Record 36 of Set 3 | khatanga
# Processing Record 37 of Set 3 | kloulklubed
# Processing Record 38 of Set 3 | shahr-e babak
# Processing Record 39 of Set 3 | cabra
# Processing Record 40 of Set 3 | punta alta
# Processing Record 41 of Set 3 | morro bay
# Processing Record 42 of Set 3 | chuy
# Processing Record 43 of Set 3 | oxapampa
# Processing Record 44 of Set 3 | hamilton
# Processing Record 45 of Set 3 | talnakh
# Processing Record 46 of Set 3 | east london
# Processing Record 47 of Set 3 | nanzhang
# Processing Record 48 of Set 3 | prattville
# Processing Record 49 of Set 3 | port antonio
# Processing Record 50 of Set 3 | tautira
# Processing Record 1 of Set 4 | santa rosa
# Processing Record 2 of Set 4 | qaanaaq
# Processing Record 3 of Set 4 | hualmay
# Processing Record 4 of Set 4 | saint-philippe
# Processing Record 5 of Set 4 | hermanus
# Processing Record 6 of Set 4 | maumere
# Processing Record 7 of Set 4 | warqla
# City not found. Skipping...
# Processing Record 8 of Set 4 | vestmannaeyjar
# Processing Record 9 of Set 4 | hedaru
# Processing Record 10 of Set 4 | kandalaksha
# Processing Record 11 of Set 4 | karkaralinsk
# City not found. Skipping...
# Processing Record 12 of Set 4 | yulara
# Processing Record 13 of Set 4 | mackay
# Processing Record 14 of Set 4 | praia da vitoria
# Processing Record 15 of Set 4 | maracaju
# Processing Record 16 of Set 4 | umzimvubu
# City not found. Skipping...
# Processing Record 17 of Set 4 | vazhiny
# Processing Record 18 of Set 4 | kirakira
# Processing Record 19 of Set 4 | kavaratti
# Processing Record 20 of Set 4 | kushima
# Processing Record 21 of Set 4 | apatou
# Processing Record 22 of Set 4 | sardinia
# Processing Record 23 of Set 4 | karratha
# Processing Record 24 of Set 4 | mar del plata
# Processing Record 25 of Set 4 | bluff
# Processing Record 26 of Set 4 | lebu
# Processing Record 27 of Set 4 | viedma
# Processing Record 28 of Set 4 | tammisaari
# Processing Record 29 of Set 4 | olafsvik
# Processing Record 30 of Set 4 | kerema
# Processing Record 31 of Set 4 | dingle
# Processing Record 32 of Set 4 | bathurst
# Processing Record 33 of Set 4 | ngunguru
# Processing Record 34 of Set 4 | mogadishu
# Processing Record 35 of Set 4 | kodinsk
# Processing Record 36 of Set 4 | elizabeth city
# Processing Record 37 of Set 4 | baffa
# Processing Record 38 of Set 4 | katsuura
# Processing Record 39 of Set 4 | port elizabeth
# Processing Record 40 of Set 4 | bredasdorp
# Processing Record 41 of Set 4 | samusu
# City not found. Skipping...
# Processing Record 42 of Set 4 | lepe
# Processing Record 43 of Set 4 | northam
# Processing Record 44 of Set 4 | araouane
# Processing Record 45 of Set 4 | ormara
# Processing Record 46 of Set 4 | muisne
# Processing Record 47 of Set 4 | ponta do sol
# Processing Record 48 of Set 4 | cockburn town
# Processing Record 49 of Set 4 | tumannyy
# City not found. Skipping...
# Processing Record 50 of Set 4 | thompson
# Processing Record 1 of Set 5 | las guacamayas
# Processing Record 2 of Set 5 | gunib
# Processing Record 3 of Set 5 | haines junction
# Processing Record 4 of Set 5 | ancud
# Processing Record 5 of Set 5 | kajansi
# Processing Record 6 of Set 5 | yarensk
# Processing Record 7 of Set 5 | belushya guba
# City not found. Skipping...
# Processing Record 8 of Set 5 | tuktoyaktuk
# Processing Record 9 of Set 5 | mabaruma
# Processing Record 10 of Set 5 | kodiak
# Processing Record 11 of Set 5 | george
# Processing Record 12 of Set 5 | bar harbor
# Processing Record 13 of Set 5 | kulhudhuffushi
# Processing Record 14 of Set 5 | camalu
# Processing Record 15 of Set 5 | aransas pass
# Processing Record 16 of Set 5 | niteroi
# Processing Record 17 of Set 5 | yaan
# Processing Record 18 of Set 5 | rawannawi
# City not found. Skipping...
# Processing Record 19 of Set 5 | sinnamary
# Processing Record 20 of Set 5 | torbay
# Processing Record 21 of Set 5 | rehoboth
# Processing Record 22 of Set 5 | grand gaube
# Processing Record 23 of Set 5 | launceston
# Processing Record 24 of Set 5 | amarillo
# Processing Record 25 of Set 5 | havoysund
# Processing Record 26 of Set 5 | chapais
# Processing Record 27 of Set 5 | kudahuvadhoo
# Processing Record 28 of Set 5 | goderich
# Processing Record 29 of Set 5 | shimoda
# Processing Record 30 of Set 5 | saskylakh
# Processing Record 31 of Set 5 | marcona
# City not found. Skipping...
# Processing Record 32 of Set 5 | baleshwar
# Processing Record 33 of Set 5 | kirov
# Processing Record 34 of Set 5 | muros
# Processing Record 35 of Set 5 | quelimane
# Processing Record 36 of Set 5 | mahaicony
# City not found. Skipping...
# Processing Record 37 of Set 5 | castro
# Processing Record 38 of Set 5 | saryshagan
# City not found. Skipping...
# Processing Record 39 of Set 5 | sisimiut
# Processing Record 40 of Set 5 | yellowknife
# Processing Record 41 of Set 5 | sug-aksy
# City not found. Skipping...
# Processing Record 42 of Set 5 | carnarvon
# Processing Record 43 of Set 5 | prince rupert
# Processing Record 44 of Set 5 | sitka
# Processing Record 45 of Set 5 | ozernovskiy
# Processing Record 46 of Set 5 | wanning
# Processing Record 47 of Set 5 | antalaha
# Processing Record 48 of Set 5 | kerteh
# City not found. Skipping...
# Processing Record 49 of Set 5 | namibe
# Processing Record 50 of Set 5 | sakakah
# Processing Record 1 of Set 6 | palabuhanratu
# City not found. Skipping...
# Processing Record 2 of Set 6 | mayo
# Processing Record 3 of Set 6 | savinka
# Processing Record 4 of Set 6 | altay
# Processing Record 5 of Set 6 | nynashamn
# Processing Record 6 of Set 6 | beira
# Processing Record 7 of Set 6 | bam
# Processing Record 8 of Set 6 | kayes
# Processing Record 9 of Set 6 | dongsheng
# Processing Record 10 of Set 6 | talakan
# Processing Record 11 of Set 6 | tema
# Processing Record 12 of Set 6 | pryazha
# Processing Record 13 of Set 6 | maragogi
# Processing Record 14 of Set 6 | macusani
# Processing Record 15 of Set 6 | sur
# Processing Record 16 of Set 6 | lompoc
# Processing Record 17 of Set 6 | sorland
# Processing Record 18 of Set 6 | grants
# Processing Record 19 of Set 6 | ituni
# City not found. Skipping...
# Processing Record 20 of Set 6 | camargo
# Processing Record 21 of Set 6 | khonuu
# City not found. Skipping...
# Processing Record 22 of Set 6 | hofn
# Processing Record 23 of Set 6 | ordynskoye
# Processing Record 24 of Set 6 | paracuru
# Processing Record 25 of Set 6 | norman wells
# Processing Record 26 of Set 6 | yerbogachen
# Processing Record 27 of Set 6 | kinablangan
# Processing Record 28 of Set 6 | pangkalanbuun
# Processing Record 29 of Set 6 | iranshahr
# Processing Record 30 of Set 6 | pindi gheb
# Processing Record 31 of Set 6 | gari
# Processing Record 32 of Set 6 | nehe
# Processing Record 33 of Set 6 | carballo
# Processing Record 34 of Set 6 | morant bay
# Processing Record 35 of Set 6 | asau
# Processing Record 36 of Set 6 | eyl
# Processing Record 37 of Set 6 | krasnorechenskiy
# Processing Record 38 of Set 6 | cabedelo
# Processing Record 39 of Set 6 | ust-kuyga
# Processing Record 40 of Set 6 | lima
# Processing Record 41 of Set 6 | mungwi
# Processing Record 42 of Set 6 | galiwinku
# City not found. Skipping...
# Processing Record 43 of Set 6 | florianopolis
# Processing Record 44 of Set 6 | loanda
# Processing Record 45 of Set 6 | sao filipe
# Processing Record 46 of Set 6 | ostersund
# Processing Record 47 of Set 6 | hambantota
# Processing Record 48 of Set 6 | cayenne
# Processing Record 49 of Set 6 | tres passos
# Processing Record 50 of Set 6 | zyryanka
# Processing Record 1 of Set 7 | husavik
# Processing Record 2 of Set 7 | middle island
# Processing Record 3 of Set 7 | kruisfontein
# Processing Record 4 of Set 7 | toliary
# City not found. Skipping...
# Processing Record 5 of Set 7 | weiz
# Processing Record 6 of Set 7 | maniitsoq
# Processing Record 7 of Set 7 | paraiso
# Processing Record 8 of Set 7 | chagda
# City not found. Skipping...
# Processing Record 9 of Set 7 | dangtu
# Processing Record 10 of Set 7 | barentsburg
# City not found. Skipping...
# Processing Record 11 of Set 7 | pangnirtung
# Processing Record 12 of Set 7 | thinadhoo
# Processing Record 13 of Set 7 | mitsamiouli
# Processing Record 14 of Set 7 | luebo
# Processing Record 15 of Set 7 | eston
# Processing Record 16 of Set 7 | zuwarah
# Processing Record 17 of Set 7 | tsihombe
# City not found. Skipping...
# Processing Record 18 of Set 7 | amderma
# City not found. Skipping...
# Processing Record 19 of Set 7 | nyzhni sirohozy
# Processing Record 20 of Set 7 | dharmadam
# Processing Record 21 of Set 7 | el balyana
# City not found. Skipping...
# Processing Record 22 of Set 7 | kidal
# Processing Record 23 of Set 7 | mweka
# Processing Record 24 of Set 7 | yubari
# Processing Record 25 of Set 7 | tunduru
# City not found. Skipping...
# Processing Record 26 of Set 7 | satitoa
# City not found. Skipping...
# Processing Record 27 of Set 7 | jinxiang
# Processing Record 28 of Set 7 | omboue
# Processing Record 29 of Set 7 | tabiauea
# City not found. Skipping...
# Processing Record 30 of Set 7 | codrington
# Processing Record 31 of Set 7 | mastic beach
# Processing Record 32 of Set 7 | malinovoye ozero
# Processing Record 33 of Set 7 | abu jubayhah
# City not found. Skipping...
# Processing Record 34 of Set 7 | bolungarvik
# City not found. Skipping...
# Processing Record 35 of Set 7 | malwan
# City not found. Skipping...
# Processing Record 36 of Set 7 | ruatoria
# City not found. Skipping...
# Processing Record 37 of Set 7 | meyungs
# City not found. Skipping...
# Processing Record 38 of Set 7 | chicama
# Processing Record 39 of Set 7 | linjiang
# Processing Record 40 of Set 7 | marquette
# Processing Record 41 of Set 7 | marzuq
# Processing Record 42 of Set 7 | kerzhenets
# City not found. Skipping...
# Processing Record 43 of Set 7 | esmeraldas
# Processing Record 44 of Set 7 | kholtoson
# Processing Record 45 of Set 7 | usinsk
# Processing Record 46 of Set 7 | alofi
# Processing Record 47 of Set 7 | tapaua
# City not found. Skipping...
# Processing Record 48 of Set 7 | airai
# Processing Record 49 of Set 7 | gat
# Processing Record 50 of Set 7 | yatou
# Processing Record 1 of Set 8 | sambava
# Processing Record 2 of Set 8 | athens
# Processing Record 3 of Set 8 | riyadh
# Processing Record 4 of Set 8 | kawalu
# Processing Record 5 of Set 8 | richards bay
# Processing Record 6 of Set 8 | jumla
# Processing Record 7 of Set 8 | san marcos de tarrazu
# City not found. Skipping...
# Processing Record 8 of Set 8 | emba
# Processing Record 9 of Set 8 | san bartolome de tirajana
# Processing Record 10 of Set 8 | srandakan
# Processing Record 11 of Set 8 | karaul
# City not found. Skipping...
# Processing Record 12 of Set 8 | bur gabo
# City not found. Skipping...
# Processing Record 13 of Set 8 | flinders
# Processing Record 14 of Set 8 | ilulissat
# Processing Record 15 of Set 8 | antofagasta
# Processing Record 16 of Set 8 | sao joao da barra
# Processing Record 17 of Set 8 | alice springs
# Processing Record 18 of Set 8 | zatoka
# Processing Record 19 of Set 8 | lavrentiya
# Processing Record 20 of Set 8 | bouza
# Processing Record 21 of Set 8 | bose
# Processing Record 22 of Set 8 | tabira
# Processing Record 23 of Set 8 | lewisporte
# Processing Record 24 of Set 8 | waipawa
# Processing Record 25 of Set 8 | clyde river
# Processing Record 26 of Set 8 | pringsewu
# Processing Record 27 of Set 8 | saint george
# Processing Record 28 of Set 8 | songjianghe
# Processing Record 29 of Set 8 | solnechnyy
# Processing Record 30 of Set 8 | zhezkazgan
# Processing Record 31 of Set 8 | kedarnath
# City not found. Skipping...
# Processing Record 32 of Set 8 | la ronge
# Processing Record 33 of Set 8 | batticaloa
# Processing Record 34 of Set 8 | chapleau
# Processing Record 35 of Set 8 | louisbourg
# City not found. Skipping...
# Processing Record 36 of Set 8 | llanes
# Processing Record 37 of Set 8 | akyab
# Processing Record 38 of Set 8 | rakaia
# Processing Record 39 of Set 8 | limerick
# Processing Record 40 of Set 8 | nuuk
# Processing Record 41 of Set 8 | rocha
# Processing Record 42 of Set 8 | zalantun
# Processing Record 43 of Set 8 | qaqortoq
# Processing Record 44 of Set 8 | cahors
# Processing Record 45 of Set 8 | ucluelet
# Processing Record 46 of Set 8 | quimperle
# Processing Record 47 of Set 8 | onega
# Processing Record 48 of Set 8 | moultrie
# Processing Record 49 of Set 8 | temaraia
# City not found. Skipping...
# Processing Record 50 of Set 8 | buritizeiro
# Processing Record 1 of Set 9 | port blair
# Processing Record 2 of Set 9 | kempele
# Processing Record 3 of Set 9 | gympie
# Processing Record 4 of Set 9 | eyemouth
# Processing Record 5 of Set 9 | liverpool
# Processing Record 6 of Set 9 | cururupu
# Processing Record 7 of Set 9 | kununurra
# Processing Record 8 of Set 9 | chulman
# Processing Record 9 of Set 9 | bemidji
# Processing Record 10 of Set 9 | georgetown
# Processing Record 11 of Set 9 | balakhta
# Processing Record 12 of Set 9 | awjilah
# Processing Record 13 of Set 9 | tanout
# Processing Record 14 of Set 9 | barranca
# Processing Record 15 of Set 9 | khandbari
# Processing Record 16 of Set 9 | mahanoro
# Processing Record 17 of Set 9 | svetlaya
# Processing Record 18 of Set 9 | krionerion
# City not found. Skipping...
# Processing Record 19 of Set 9 | portland
# Processing Record 20 of Set 9 | asyut
# Processing Record 21 of Set 9 | belmonte
# Processing Record 22 of Set 9 | tornio
# Processing Record 23 of Set 9 | champerico
# Processing Record 24 of Set 9 | sabha
# Processing Record 25 of Set 9 | hithadhoo
# Processing Record 26 of Set 9 | koumac
# Processing Record 27 of Set 9 | oum hadjer
# Processing Record 28 of Set 9 | saldana
# Processing Record 29 of Set 9 | szczecinek
# Processing Record 30 of Set 9 | sol-iletsk
# Processing Record 31 of Set 9 | sangar
# Processing Record 32 of Set 9 | mount isa
# Processing Record 33 of Set 9 | kuito
# Processing Record 34 of Set 9 | moron
# Processing Record 35 of Set 9 | vardo
# Processing Record 36 of Set 9 | hasaki
# Processing Record 37 of Set 9 | pontianak
# Processing Record 38 of Set 9 | lagoa
# Processing Record 39 of Set 9 | kahului
# Processing Record 40 of Set 9 | gangapur
# Processing Record 41 of Set 9 | barraute
# Processing Record 42 of Set 9 | uk
# City not found. Skipping...
# Processing Record 43 of Set 9 | westport
# Processing Record 44 of Set 9 | makaha
# Processing Record 45 of Set 9 | georgiyevka
# Processing Record 46 of Set 9 | homer
# Processing Record 47 of Set 9 | lewistown
# Processing Record 48 of Set 9 | youghal
# Processing Record 49 of Set 9 | benjamin constant
# Processing Record 50 of Set 9 | bilma
# Processing Record 1 of Set 10 | amarpur
# Processing Record 2 of Set 10 | huarmey
# Processing Record 3 of Set 10 | melioratorov
# Processing Record 4 of Set 10 | pozo colorado
# Processing Record 5 of Set 10 | necochea
# Processing Record 6 of Set 10 | ulundi
# Processing Record 7 of Set 10 | genoa
# Processing Record 8 of Set 10 | igrim
# Processing Record 9 of Set 10 | steinbach
# Processing Record 10 of Set 10 | aksarka
# Processing Record 11 of Set 10 | valdivia
# Processing Record 12 of Set 10 | quetzaltepec
# City not found. Skipping...
# Processing Record 13 of Set 10 | kolobrzeg
# Processing Record 14 of Set 10 | kuala terengganu
# Processing Record 15 of Set 10 | half moon bay
# Processing Record 16 of Set 10 | neiafu
# Processing Record 17 of Set 10 | la union
# Processing Record 18 of Set 10 | ostrovnoy
# Processing Record 19 of Set 10 | puerto ayacucho
# Processing Record 20 of Set 10 | egvekinot
# Processing Record 21 of Set 10 | hue
# Processing Record 22 of Set 10 | pimentel
# Processing Record 23 of Set 10 | yeniseysk
# Processing Record 24 of Set 10 | cap malheureux
# Processing Record 25 of Set 10 | padang
# Processing Record 26 of Set 10 | lamu
# Processing Record 27 of Set 10 | archidona
# Processing Record 28 of Set 10 | ouro preto
# Processing Record 29 of Set 10 | skjervoy
# Processing Record 30 of Set 10 | lolua
# City not found. Skipping...
# Processing Record 31 of Set 10 | umm lajj
# Processing Record 32 of Set 10 | arcata
# Processing Record 33 of Set 10 | kamyshin
# Processing Record 34 of Set 10 | great yarmouth
# Processing Record 35 of Set 10 | arona
# Processing Record 36 of Set 10 | poiana stampei
# Processing Record 37 of Set 10 | poya
# Processing Record 38 of Set 10 | grindavik
# Processing Record 39 of Set 10 | pathalgaon
# Processing Record 40 of Set 10 | honiara
# Processing Record 41 of Set 10 | saint-laurent-du-var
# Processing Record 42 of Set 10 | leningradskiy
# Processing Record 43 of Set 10 | wattegama
# Processing Record 44 of Set 10 | hagi
# Processing Record 45 of Set 10 | kolosovka
# Processing Record 46 of Set 10 | atar
# Processing Record 47 of Set 10 | merauke
# Processing Record 48 of Set 10 | komsomolskiy
# Processing Record 49 of Set 10 | meulaboh
# Processing Record 50 of Set 10 | petropavlovsk-kamchatskiy
# Processing Record 1 of Set 11 | mwinilunga
# Processing Record 2 of Set 11 | turan
# Processing Record 3 of Set 11 | dobric
# Processing Record 4 of Set 11 | bairiki
# Processing Record 5 of Set 11 | wewak
# Processing Record 6 of Set 11 | we
# City not found. Skipping...
# Processing Record 7 of Set 11 | hami
# Processing Record 8 of Set 11 | fairbanks
# Processing Record 9 of Set 11 | basoko
# Processing Record 10 of Set 11 | saint-pierre
# Processing Record 11 of Set 11 | undory
# Processing Record 12 of Set 11 | itupiranga
# Processing Record 13 of Set 11 | karla
# Processing Record 14 of Set 11 | mmabatho
# Processing Record 15 of Set 11 | moratuwa
# Processing Record 16 of Set 11 | mentok
# City not found. Skipping...
# Processing Record 17 of Set 11 | huaidian
# Processing Record 18 of Set 11 | saint-raphael
# Processing Record 19 of Set 11 | lithgow
# Processing Record 20 of Set 11 | callaway
# Processing Record 21 of Set 11 | verkhoyansk
# Processing Record 22 of Set 11 | tagusao
# Processing Record 23 of Set 11 | isangel
# Processing Record 24 of Set 11 | talkha
# Processing Record 25 of Set 11 | erzincan
# Processing Record 26 of Set 11 | bezhetsk
# Processing Record 27 of Set 11 | kaseda
# Processing Record 28 of Set 11 | katha
# City not found. Skipping...
# Processing Record 29 of Set 11 | harnosand
# Processing Record 30 of Set 11 | salta
# Processing Record 31 of Set 11 | sterling
# Processing Record 32 of Set 11 | north platte
# Processing Record 33 of Set 11 | ternate
# Processing Record 34 of Set 11 | teya
# Processing Record 35 of Set 11 | vershino-shakhtaminskiy
# Processing Record 36 of Set 11 | hervey bay
# Processing Record 37 of Set 11 | tual
# Processing Record 38 of Set 11 | santa cruz
# Processing Record 39 of Set 11 | laiwu
# Processing Record 40 of Set 11 | zhigalovo
# Processing Record 41 of Set 11 | iskateley
# Processing Record 42 of Set 11 | puerto escondido
# Processing Record 43 of Set 11 | luanda
# Processing Record 44 of Set 11 | dekar
# Processing Record 45 of Set 11 | balykshi
# Processing Record 46 of Set 11 | waitati
# Processing Record 47 of Set 11 | grand river south east
# City not found. Skipping...
# Processing Record 48 of Set 11 | paracatu
# Processing Record 49 of Set 11 | matara
# Processing Record 50 of Set 11 | oktyabrskoye
# Processing Record 1 of Set 12 | san carlos
# Processing Record 2 of Set 12 | maceio
# Processing Record 3 of Set 12 | las palmas
# Processing Record 4 of Set 12 | saint-denis
# Processing Record 5 of Set 12 | mayya
# Processing Record 6 of Set 12 | victor harbor
# Processing Record 7 of Set 12 | gladstone
# Processing Record 8 of Set 12 | pangai
# Processing Record 9 of Set 12 | volkhov
# Processing Record 10 of Set 12 | inirida
# Processing Record 11 of Set 12 | belaya gora
# Processing Record 12 of Set 12 | tir pol
# City not found. Skipping...
# Processing Record 13 of Set 12 | te anau
# Processing Record 14 of Set 12 | jibuti
# Processing Record 15 of Set 12 | samarai
# Processing Record 16 of Set 12 | oyama
# Processing Record 17 of Set 12 | linhares
# Processing Record 18 of Set 12 | jingdezhen
# Processing Record 19 of Set 12 | kamaishi
# Processing Record 20 of Set 12 | kizhinga
# Processing Record 21 of Set 12 | key west
# Processing Record 22 of Set 12 | erenhot
# Processing Record 23 of Set 12 | saint-francois
# Processing Record 24 of Set 12 | qui nhon
# Processing Record 25 of Set 12 | gao
# Processing Record 26 of Set 12 | tam ky
# Processing Record 27 of Set 12 | galle
# Processing Record 28 of Set 12 | pimenta bueno
# Processing Record 29 of Set 12 | otane
# Processing Record 30 of Set 12 | vaitape
# Processing Record 31 of Set 12 | villamontes
# Processing Record 32 of Set 12 | solikamsk
# Processing Record 33 of Set 12 | itarema
# Processing Record 34 of Set 12 | paldiski
# Processing Record 35 of Set 12 | tarija
# Processing Record 36 of Set 12 | tezu
# Processing Record 37 of Set 12 | boda
# Processing Record 38 of Set 12 | berbera
# Processing Record 39 of Set 12 | conceicao do araguaia
# Processing Record 40 of Set 12 | bawku
# Processing Record 41 of Set 12 | bang bo
# Processing Record 42 of Set 12 | goundam
# Processing Record 43 of Set 12 | ilula
# Processing Record 44 of Set 12 | shingu
# Processing Record 45 of Set 12 | rio grande
# Processing Record 46 of Set 12 | andros
# Processing Record 47 of Set 12 | kandrian
# Processing Record 48 of Set 12 | kyrylivka
# Processing Record 49 of Set 12 | luwuk
# Processing Record 50 of Set 12 | mayor pablo lagerenza
# Processing Record 1 of Set 13 | tres lagoas
# Processing Record 2 of Set 13 | bathsheba
# Processing Record 3 of Set 13 | geraldton
# Processing Record 4 of Set 13 | nguiu
# City not found. Skipping...
# Processing Record 5 of Set 13 | calvinia
# Processing Record 6 of Set 13 | buala
# Processing Record 7 of Set 13 | ust-nera
# Processing Record 8 of Set 13 | sandwick
# Processing Record 9 of Set 13 | camana
# Processing Record 10 of Set 13 | huilong
# Processing Record 11 of Set 13 | chumphon
# Processing Record 12 of Set 13 | holme
# Processing Record 13 of Set 13 | kaeo
# Processing Record 14 of Set 13 | tilichiki
# Processing Record 15 of Set 13 | dumai
# Processing Record 16 of Set 13 | pacific grove
# Processing Record 17 of Set 13 | cruzeiro
# Processing Record 18 of Set 13 | grebanu
# Processing Record 19 of Set 13 | grand-santi
# Processing Record 20 of Set 13 | la paz
# Processing Record 21 of Set 13 | loiza
# Processing Record 22 of Set 13 | kankan
# Processing Record 23 of Set 13 | ongandjera
# Processing Record 24 of Set 13 | kostenec
# City not found. Skipping...
# Processing Record 25 of Set 13 | trairi
# Processing Record 26 of Set 13 | quetta
# Processing Record 27 of Set 13 | broome
# Processing Record 28 of Set 13 | kysyl-syr
# Processing Record 29 of Set 13 | abnub
# Processing Record 30 of Set 13 | bikin
# Processing Record 31 of Set 13 | nioro
# Processing Record 32 of Set 13 | samalaeulu
# City not found. Skipping...
# Processing Record 33 of Set 13 | xuddur
# Processing Record 34 of Set 13 | fort nelson
# Processing Record 35 of Set 13 | lethem
# Processing Record 36 of Set 13 | vikarabad
# Processing Record 37 of Set 13 | pouembout
# Processing Record 38 of Set 13 | xichang
# Processing Record 39 of Set 13 | havelock
# Processing Record 40 of Set 13 | sayyan
# Processing Record 41 of Set 13 | inhuma
# Processing Record 42 of Set 13 | osa
# Processing Record 43 of Set 13 | garowe
# Processing Record 44 of Set 13 | vanersborg
# Processing Record 45 of Set 13 | radnevo
# Processing Record 46 of Set 13 | svetlogorsk
# Processing Record 47 of Set 13 | garissa
# Processing Record 48 of Set 13 | ramnagar
# Processing Record 49 of Set 13 | varhaug
# Processing Record 50 of Set 13 | ksenyevka
# City not found. Skipping...
# Processing Record 1 of Set 14 | bargal
# City not found. Skipping...
# Processing Record 2 of Set 14 | laibin
# Processing Record 3 of Set 14 | sumbe
# Processing Record 4 of Set 14 | qiryat shemona
# Processing Record 5 of Set 14 | yanam
# Processing Record 6 of Set 14 | armacao dos buzios
# City not found. Skipping...
# Processing Record 7 of Set 14 | nelson bay
# Processing Record 8 of Set 14 | moussoro
# Processing Record 9 of Set 14 | caravelas
# Processing Record 10 of Set 14 | qandahar
# City not found. Skipping...
# Processing Record 11 of Set 14 | kangaatsiaq
# Processing Record 12 of Set 14 | san policarpo
# Processing Record 13 of Set 14 | sept-iles
# Processing Record 14 of Set 14 | tiznit
# Processing Record 15 of Set 14 | maluay
# City not found. Skipping...
# Processing Record 16 of Set 14 | ahipara
# Processing Record 17 of Set 14 | natal
# Processing Record 18 of Set 14 | yurino
# Processing Record 19 of Set 14 | axim
# Processing Record 20 of Set 14 | tuckahoe
# Processing Record 21 of Set 14 | henties bay
# Processing Record 22 of Set 14 | lokot
# Processing Record 23 of Set 14 | saint anthony
# Processing Record 24 of Set 14 | springdale
# Processing Record 25 of Set 14 | igarka
# Processing Record 26 of Set 14 | kitimat
# Processing Record 27 of Set 14 | mawlaik
# Processing Record 28 of Set 14 | plettenberg bay
# Processing Record 29 of Set 14 | sioux lookout
# Processing Record 30 of Set 14 | onalaska
# Processing Record 31 of Set 14 | san cristobal
# Processing Record 32 of Set 14 | maple creek
# Processing Record 33 of Set 14 | port hardy
# Processing Record 34 of Set 14 | takoradi
# Processing Record 35 of Set 14 | romans-sur-isere
# Processing Record 36 of Set 14 | abha
# Processing Record 37 of Set 14 | mrirt
# City not found. Skipping...
# Processing Record 38 of Set 14 | santa lucia
# Processing Record 39 of Set 14 | shadrinsk
# Processing Record 40 of Set 14 | yantal
# Processing Record 41 of Set 14 | kashi
# Processing Record 42 of Set 14 | tura
# Processing Record 43 of Set 14 | vao
# Processing Record 44 of Set 14 | rolim de moura
# City not found. Skipping...
# Processing Record 45 of Set 14 | muravlenko
# Processing Record 46 of Set 14 | soubre
# Processing Record 47 of Set 14 | portree
# Processing Record 48 of Set 14 | port hedland
# Processing Record 49 of Set 14 | nchelenge
# Processing Record 50 of Set 14 | general roca
# Processing Record 1 of Set 15 | vestmanna
# Processing Record 2 of Set 15 | krasnoarmeysk
# Processing Record 3 of Set 15 | pisco
# Processing Record 4 of Set 15 | shelburne
# Processing Record 5 of Set 15 | inhambane
# Processing Record 6 of Set 15 | puerto pinasco
# City not found. Skipping...
# Processing Record 7 of Set 15 | yomitan
# City not found. Skipping...
# Processing Record 8 of Set 15 | murgab
# Processing Record 9 of Set 15 | margate
# Processing Record 10 of Set 15 | mandalgovi
# Processing Record 11 of Set 15 | sinjai
# Processing Record 12 of Set 15 | apatity
# Processing Record 13 of Set 15 | copiapo
# Processing Record 14 of Set 15 | faya
# Processing Record 15 of Set 15 | rio verde de mato grosso
# Processing Record 16 of Set 15 | arkhangelos
# City not found. Skipping...
# Processing Record 17 of Set 15 | novobiryusinskiy
# Processing Record 18 of Set 15 | mareeba
# Processing Record 19 of Set 15 | dewas
# Processing Record 20 of Set 15 | kommunisticheskiy
# Processing Record 21 of Set 15 | campoverde
# Processing Record 22 of Set 15 | zhangye
# Processing Record 23 of Set 15 | talara
# Processing Record 24 of Set 15 | barcelona
# Processing Record 25 of Set 15 | kardla
# Processing Record 26 of Set 15 | linqiong
# Processing Record 27 of Set 15 | navalmoral de la mata
# Processing Record 28 of Set 15 | uttarkashi
# Processing Record 29 of Set 15 | bull savanna
# Processing Record 30 of Set 15 | taoudenni
# Processing Record 31 of Set 15 | shatki
# Processing Record 32 of Set 15 | yurla
# Processing Record 33 of Set 15 | salinopolis
# Processing Record 34 of Set 15 | paredon
# Processing Record 35 of Set 15 | calhoun
# Processing Record 36 of Set 15 | marapanim
# Processing Record 37 of Set 15 | paamiut
# Processing Record 38 of Set 15 | san andres
# Processing Record 39 of Set 15 | iriron
# City not found. Skipping...
# Processing Record 40 of Set 15 | noumea
# Processing Record 41 of Set 15 | ladario
# Processing Record 42 of Set 15 | burica
# City not found. Skipping...
# Processing Record 43 of Set 15 | alpena
# Processing Record 44 of Set 15 | flin flon
# Processing Record 45 of Set 15 | takestan
# Processing Record 46 of Set 15 | udachnyy
# Processing Record 47 of Set 15 | hailey
# Processing Record 48 of Set 15 | ekhabi
# Processing Record 49 of Set 15 | dennery
# Processing Record 50 of Set 15 | eenhana
# Processing Record 1 of Set 16 | mattru
# Processing Record 2 of Set 16 | ginir
# Processing Record 3 of Set 16 | ust-ishim
# Processing Record 4 of Set 16 | yarada
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 681

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#            City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0   Port Alfred      ZA -33.5906   26.8910     59.27        57           0
# 1        Tadine      NC -21.5500  167.8833     71.19        74          22
# 2     Busselton      AU -33.6500  115.3333     59.09        88         100
# 3        Faanui      PF -16.4833 -151.7500     81.79        73           5
# 4  Puerto Ayora      EC  -0.7393  -90.3518     75.54        91          94
# 5        Kibaya      TZ  -5.3000   36.5667     66.94        60          22
# 6          Rena      NO  61.1348   11.3641     49.82        70          89
# 7    Butaritari      KI   3.0707  172.7902     83.61        79         100
# 8      Matagami      CA  49.7502  -77.6328     59.11        97          90
# 9  Punta Arenas      CL -53.1500  -70.9167     41.11        86          20
#
#    Wind Speed Current Description
# 0       12.19           clear sky
# 1       11.92          light rain
# 2       17.05          light rain
# 3       13.60           clear sky
# 4       10.00     overcast clouds
# 5        5.57          few clouds
# 6        3.36     overcast clouds
# 7       19.51     overcast clouds
# 8        5.82     overcast clouds
# 9        4.05          few clouds

# %%
# Create the output file (CSV).
output_data_file = "Weather_Database/WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
